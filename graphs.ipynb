# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rk4 = pd.read_csv("data/rk4.csv", sep=" ")
plt.plot(rk4.loc[:, "t"], rk4.loc[:, "x"])

heun = pd.read_csv("data/heun.csv", sep=" ")
plt.plot(heun.loc[:, "t"], heun.loc[:, "x"])

#euler = pd.read_csv("data/euler.csv", sep=" ")
#plt.plot(euler.loc[:, "t"], euler.loc[:, "x"])

# %%
rk4 = pd.read_csv("data/rk4_friction.csv", sep=" ")
plt.plot(rk4.loc[:, "t"], rk4.loc[:, "x"])

heun = pd.read_csv("data/heun_friction.csv", sep=" ")
plt.plot(heun.loc[:, "t"], heun.loc[:, "x"])

euler = pd.read_csv("data/euler_friction.csv", sep=" ")
plt.plot(euler.loc[:, "t"], euler.loc[:, "x"])

# %%
import subprocess
p = subprocess.Popen(["./task1 config.json"], stderr=subprocess.PIPE, stdout=subprocess.PIPE, shell=True)
out, err = p.communicate()
out, err
# Out:
# (b'{"algorithm":"rk4","datatype":"float","f":1,"friction":1.0,"name":"periodic_force","omega":0.05,"omega_0":0.75,"step":0.2,"x0":5,"y0":0}\n',
#  b'')

# %%
rk4 = pd.read_csv("data/rk4_periodic_force.csv", sep=" ")
plt.plot(rk4.loc[:, "t"], rk4.loc[:, "x"])

# euler = pd.read_csv("data/euler_periodic_force.csv", sep=" ")
# plt.plot(euler.loc[:, "t"], euler.loc[:, "x"])

# heun = pd.read_csv("data/heun_periodic_force.csv", sep=" ")
# plt.plot(heun.loc[:, "t"], heun.loc[:, "x"])
